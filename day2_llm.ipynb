# %%
from sentence_transformers import SentenceTransformer, util

# %%
dataset = ["FakeCom is a fake company created to spread fake news",
           "All members of FakeCom company must pay an annual fee of $100 to stay in the company",
           "The members are liable for any damage caused by the news they spread",
           "A weekly meeting will be conducted at the Town hall for the members to meet each other and spread fake news",
           "The members are not allowed to spread fake news about the other members of the company",
           "If a member wishes to leave the company, he have to pay a fee of $250 and also take an oath that he/she will not spread fake news ever again in their lives.",
           "Members are expected to wear  white clothes to the meeting",
           "Members should not spread fake news about the company itself",
           "Members are not allowed to use any social media except facebook.",
           "All members should have a fake name while attending meetings that start with the letter F"]

# %%
len(dataset)
# Out:
# 10

# %%
model=SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
data_embeddings=model.encode(dataset)

# %%
data_embeddings.shape
# Out:
# (10, 384)

# %%
query="What is the company policy on fake news?"
